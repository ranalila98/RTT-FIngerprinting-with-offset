# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os

#combining no of csv file into one file with name combine_csv
os.chdir(r'C:\Users\LILA\Desktop\RTT-FIngerprinting-with-offset\RTT-Fingerprinting with offset\Output')
extension='csv'


# load data from CSV file
df1 = pd.read_csv('output_data_no_ex.csv')
df2 = pd.read_csv('output_data__KNN_no_ex.csv')
df3 = pd.read_csv('trilaterantion_callibrated.csv')
df4 = pd.read_csv('output_data_dnn_no_ex.csv')
# df5 = pd.read_csv('output_data_with_ex_RF.csv')
# df6 = pd.read_csv('output_data_with_ex_knn.csv')
# df7 = pd.read_csv('output_data_no_ex_RF.csv')
# df8 = pd.read_csv('output_data_no_ex_knn.csv')



# calculate MSE for each sample
mse_x1 = np.array(df1['x'] - df1['predicted_x'])**2
#mse_x1=np.sqrt(mse_x1)
mse_y1 = np.array(df1['y'] - df1['predicted_y'])**2
#mse_y1=np.sqrt(mse_y1)
# calculate MSE for each sample
#mse_x1 = np.array(df1['x'] - df1['predicted_x'])
#mse_y1 = np.array(df1['y'] - df1['predicted_y'])
# calculate MSE for each sample
mse_x2 = np.array(df2['x'] - df2['predicted_x'])**2
# #mse_x2=np.sqrt(mse_x2)
mse_y2 = np.array(df2['y'] - df2['predicted_y'])**2
#mse_y2=np.sqrt(mse_y2)
#mse_x2 = np.array(df2['x'] - df2['predicted_x'])
#mse_y2 = np.array(df2['y'] - df2['predicted_y'])
mse_x3 = np.array(df3['x'] - df3['predicted_x'])**2
# #mse_x1=np.sqrt(mse_x1)
mse_y3 = np.array(df3['y'] - df3['predicted_y'])**2
#mse_y1=np.sqrt(mse_y1) 
mse_x4 = np.array(df4['x'] - df4['predicted_x'])**2
#mse_x1=np.sqrt(mse_x1)
mse_y4 = np.array(df4['y'] - df4['predicted_y'])**2

# mse_x5 = np.array(df5['x'] - df5['predicted_x'])**2
# mse_y5 = np.array(df5['y'] - df5['predicted_y'])**2

# mse_x6 = np.array(df6['x'] - df6['predicted_x'])**2
# mse_y6 = np.array(df6['y'] - df6['predicted_y'])**2

# mse_x7 = np.array(df7['x'] - df7['predicted_x'])**2
# mse_y7 = np.array(df7['y'] - df7['predicted_y'])**2

# mse_x8 = np.array(df8['x'] - df8['predicted_x'])**2
# mse_y8 = np.array(df8['y'] - df8['predicted_y'])**2


                  
                  
# calculate total MSE
mse1 = mse_x1 + mse_y1
mse2 = mse_x2 + mse_y2
mse3 = mse_x3 + mse_y3 
mse4 = mse_x4 + mse_y4 
# mse5 = mse_x5 + mse_y5
# mse6 = mse_x6 + mse_y6
# mse7 = mse_x7 + mse_y7 
# mse8 = mse_x8 + mse_y8




sorted_mse1=np.sort(mse1)
sorted_mse2=np.sort(mse2)
sorted_mse3=np.sort(mse3)
sorted_mse4=np.sort(mse4)
# sorted_mse5=np.sort(mse5)
# sorted_mse6=np.sort(mse6)
# sorted_mse7=np.sort(mse7)
# sorted_mse8=np.sort(mse8)




# calculate CDF of MSE values
cdf1=np.arange(len(sorted_mse1))/float(len(sorted_mse1))
cdf2=np.arange(len(sorted_mse2))/float(len(sorted_mse2))

cdf3=np.arange(len(sorted_mse3))/float(len(sorted_mse3))
cdf4=np.arange(len(sorted_mse4))/float(len(sorted_mse4))

# cdf5=np.arange(len(sorted_mse5))/float(len(sorted_mse5))
# cdf6=np.arange(len(sorted_mse6))/float(len(sorted_mse6))

# cdf7=np.arange(len(sorted_mse7))/float(len(sorted_mse7))
# cdf8=np.arange(len(sorted_mse8))/float(len(sorted_mse8))






#cdf1 = np.array(np.cumsum(sorted_mse1) / np.sum(sorted_mse1))
#cdf2 = np.array(np.cumsum(sorted_mse2) / np.sum(sorted_mse2))
#cdf3 = np.array(np.cumsum(sorted_mse3) / np.sum(sorted_mse3))
#cdf4 = np.array(np.cumsum(sorted_mse4) / np.sum(sorted_mse4))

# calculate the empirical CDF
#n1 = len(sorted_mse1)
#cdf1 = np.arange(1, n1+1) / n1
#n2 = len(sorted_mse2)
#cdf2 = np.arange(1, n2+1) / n2
#n3 = len(sorted_mse3)
#cdf3 = np.arange(1, n3+1) / n3

#n4 = len(sorted_mse4)
#cdf4 = np.arange(1, n4+1) / n4

# %%
plt.xlabel('Localization Error (MSE)')
plt.ylabel('CDF')
#plt.title('CDF using sorting the data')

# plt.plot(sorted_mse3, cdf3, label='Trilateration')
plt.plot(sorted_mse4, cdf4 ,label='DNN only')
plt.plot(sorted_mse2, cdf2, label='DNN+KNN')
plt.plot(sorted_mse1, cdf1, label='DNN+RF')

plt.legend()
plt.ylim([0, 1])
# plt.xlim([0, 10])
plt.grid()
# Get the path to the desktop directory
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")

# Save the plot as a PDF file on the desktop
plt.savefig(os.path.join(desktop_path, "cdf_ref_points.pdf"), format='pdf')
plt.show()

# %%
#combining no of csv file into one file with name combine_csv
os.chdir(r'C:\Users\LILA\Desktop\RTT-FIngerprinting-with-offset\RTT-Fingerprinting with offset\Output')
extension='csv'


# load data from CSV file
df1 = pd.read_csv('output_data_no_offset.csv')
df2 = pd.read_csv('output_data__KNN_no_offset.csv')
df3 = pd.read_csv('trilaterantion_raw.csv')
df4 = pd.read_csv('output_data_dnn_no_offset.csv')
# df5 = pd.read_csv('output_data_with_ex_RF.csv')
# df6 = pd.read_csv('output_data_with_ex_knn.csv')
# df7 = pd.read_csv('output_data_no_ex_RF.csv')
# df8 = pd.read_csv('output_data_no_ex_knn.csv')



# calculate MSE for each sample
mse_x1 = np.array(df1['x'] - df1['predicted_x'])**2
#mse_x1=np.sqrt(mse_x1)
mse_y1 = np.array(df1['y'] - df1['predicted_y'])**2
#mse_y1=np.sqrt(mse_y1)
# calculate MSE for each sample
#mse_x1 = np.array(df1['x'] - df1['predicted_x'])
#mse_y1 = np.array(df1['y'] - df1['predicted_y'])
# calculate MSE for each sample
mse_x2 = np.array(df2['x'] - df2['predicted_x'])**2
# #mse_x2=np.sqrt(mse_x2)
mse_y2 = np.array(df2['y'] - df2['predicted_y'])**2
#mse_y2=np.sqrt(mse_y2)
#mse_x2 = np.array(df2['x'] - df2['predicted_x'])
#mse_y2 = np.array(df2['y'] - df2['predicted_y'])
mse_x3 = np.array(df3['x'] - df3['predicted_x'])**2
# #mse_x1=np.sqrt(mse_x1)
mse_y3 = np.array(df3['y'] - df3['predicted_y'])**2
#mse_y1=np.sqrt(mse_y1) 
mse_x4 = np.array(df4['x'] - df4['predicted_x'])**2
#mse_x1=np.sqrt(mse_x1)
mse_y4 = np.array(df4['y'] - df4['predicted_y'])**2

# mse_x5 = np.array(df5['x'] - df5['predicted_x'])**2
# mse_y5 = np.array(df5['y'] - df5['predicted_y'])**2

# mse_x6 = np.array(df6['x'] - df6['predicted_x'])**2
# mse_y6 = np.array(df6['y'] - df6['predicted_y'])**2

# mse_x7 = np.array(df7['x'] - df7['predicted_x'])**2
# mse_y7 = np.array(df7['y'] - df7['predicted_y'])**2

# mse_x8 = np.array(df8['x'] - df8['predicted_x'])**2
# mse_y8 = np.array(df8['y'] - df8['predicted_y'])**2


                  
                  
# calculate total MSE
mse1 = mse_x1 + mse_y1
mse2 = mse_x2 + mse_y2
mse3 = mse_x3 + mse_y3 
mse4 = mse_x4 + mse_y4 
# mse5 = mse_x5 + mse_y5
# mse6 = mse_x6 + mse_y6
# mse7 = mse_x7 + mse_y7 
# mse8 = mse_x8 + mse_y8




sorted_mse1=np.sort(mse1)
sorted_mse2=np.sort(mse2)
sorted_mse3=np.sort(mse3)
sorted_mse4=np.sort(mse4)
# sorted_mse5=np.sort(mse5)
# sorted_mse6=np.sort(mse6)
# sorted_mse7=np.sort(mse7)
# sorted_mse8=np.sort(mse8)




# calculate CDF of MSE values
cdf1=np.arange(len(sorted_mse1))/float(len(sorted_mse1))
cdf2=np.arange(len(sorted_mse2))/float(len(sorted_mse2))

cdf3=np.arange(len(sorted_mse3))/float(len(sorted_mse3))
cdf4=np.arange(len(sorted_mse4))/float(len(sorted_mse4))

# cdf5=np.arange(len(sorted_mse5))/float(len(sorted_mse5))
# cdf6=np.arange(len(sorted_mse6))/float(len(sorted_mse6))

# cdf7=np.arange(len(sorted_mse7))/float(len(sorted_mse7))
# cdf8=np.arange(len(sorted_mse8))/float(len(sorted_mse8))

# %%
plt.xlabel('Localization Error(Mean Squared Error)')
plt.ylabel('CDF')
#plt.title('CDF using sorting the data')

plt.plot(sorted_mse3, cdf3, label='Trilateration')
plt.plot(sorted_mse4, cdf4 ,label='DNN only')
plt.plot(sorted_mse2, cdf2, label='DNN+KNN')
plt.plot(sorted_mse1, cdf1, label='DNN+RF')


plt.legend()
# plt.ylim([0, 2])
plt.xlim([0, 20])
plt.grid()
plt.show()
plt.savefig('first_plot.pdf', format='pdf')

# %%
# load data from CSV file
df1 = pd.read_csv('output_data_DNNRF_randomtest_offset.csv')
df2 = pd.read_csv('output_data__KNN_randomtest_offset.csv')
df3 = pd.read_csv('output_data_dnn_random_test_offset.csv')
# df4=  pd.read_csv('trilaterantion_random test_callibrated.csv')


# calculate MSE for each sample
mse_x1 = np.array(df1['x'] - df1['predicted_x'])**2
mse_y1 = np.array(df1['y'] - df1['predicted_y'])**2
# calculate MSE for each sample
mse_x2 = np.array(df2['x'] - df2['predicted_x'])**2
# #mse_x2=np.sqrt(mse_x2)
mse_y2 = np.array(df2['y'] - df2['predicted_y'])**2

mse_x3 = np.array(df3['x'] - df3['predicted_x'])**2
# #mse_x1=np.sqrt(mse_x1)
mse_y3 = np.array(df3['y'] - df3['predicted_y'])**2
#mse_y1=np.sqrt(mse_y1) 
# mse_x4 = np.array(df4['x'] - df4['predicted_x'])**2
#mse_x1=np.sqrt(mse_x1)
# mse_y4 = np.array(df4['y'] - df4['predicted_y'])**2





                  
                  
# calculate total MSE
mse1 = mse_x1 + mse_y1
mse2 = mse_x2 + mse_y2
mse3 = mse_x3 + mse_y3 
# mse4 = mse_x4 + mse_y4 




sorted_mse1=np.sort(mse1)
sorted_mse2=np.sort(mse2)
sorted_mse3=np.sort(mse3)
# sorted_mse4=np.sort(mse4)




# calculate CDF of MSE values
cdf1=np.arange(len(sorted_mse1))/float(len(sorted_mse1))
cdf2=np.arange(len(sorted_mse2))/float(len(sorted_mse2))

cdf3=np.arange(len(sorted_mse3))/float(len(sorted_mse3))
# cdf4=np.arange(len(sorted_mse4))/float(len(sorted_mse4))

# %%
plt.xlabel('Localization Error (MSE)')
plt.ylabel('CDF')
#plt.title('CDF using sorting the data')

plt.plot(sorted_mse3, cdf3 ,label='DNN',)
plt.plot(sorted_mse2, cdf2, label='DNN+KNN')
plt.plot(sorted_mse1, cdf1, label='DNN+RF' )
#plt.plot(sorted_mse4, cdf4, label='Tri')


plt.legend()
plt.ylim([0, 1])
# plt.xlim([0, 20])
plt.grid()
# Get the path to the desktop directory
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")

# Save the plot as a PDF file on the desktop
plt.savefig(os.path.join(desktop_path, "cdf_randompoints.pdf"), format='pdf')
plt.show()

# %%
# load data from CSV file
df1 = pd.read_csv('output_data_randomtest_no_offset.csv')
df2 = pd.read_csv('output_data__KNN_randomtest_no_offset.csv')
df3 = pd.read_csv('output_data_dnn_randomtest_no_offset.csv')
# df4=  pd.read_csv('trilaterantion_random test_callibrated.csv')


# calculate MSE for each sample
mse_x1 = np.array(df1['x'] - df1['predicted_x'])**2
mse_y1 = np.array(df1['y'] - df1['predicted_y'])**2
# calculate MSE for each sample
mse_x2 = np.array(df2['x'] - df2['predicted_x'])**2
# #mse_x2=np.sqrt(mse_x2)
mse_y2 = np.array(df2['y'] - df2['predicted_y'])**2

mse_x3 = np.array(df3['x'] - df3['predicted_x'])**2
# #mse_x1=np.sqrt(mse_x1)
mse_y3 = np.array(df3['y'] - df3['predicted_y'])**2
#mse_y1=np.sqrt(mse_y1) 
# mse_x4 = np.array(df4['x'] - df4['predicted_x'])**2
#mse_x1=np.sqrt(mse_x1)
# mse_y4 = np.array(df4['y'] - df4['predicted_y'])**2





                  
                  
# calculate total MSE
mse1 = mse_x1 + mse_y1
mse2 = mse_x2 + mse_y2
mse3 = mse_x3 + mse_y3 
# mse4 = mse_x4 + mse_y4 




sorted_mse1=np.sort(mse1)
sorted_mse2=np.sort(mse2)
sorted_mse3=np.sort(mse3)
# sorted_mse4=np.sort(mse4)




# calculate CDF of MSE values
cdf1=np.arange(len(sorted_mse1))/float(len(sorted_mse1))
cdf2=np.arange(len(sorted_mse2))/float(len(sorted_mse2))

cdf3=np.arange(len(sorted_mse3))/float(len(sorted_mse3))
# cdf4=np.arange(len(sorted_mse4))/float(len(sorted_mse4))

# %%
plt.xlabel('Mean Squared Error(m)')
plt.ylabel('CDF')
#plt.title('CDF using sorting the data')

plt.plot(sorted_mse3, cdf3 ,label='DNN',marker='>')
plt.plot(sorted_mse2, cdf2, label='DNN+KNN',marker='<')
plt.plot(sorted_mse1, cdf1, label='DNN+RF',marker='*' )
#plt.plot(sorted_mse4, cdf4, label='Tri')


plt.legend()
plt.ylim([0, 1])
#plt.xlim([0, 20])
plt.grid()
plt.show()
