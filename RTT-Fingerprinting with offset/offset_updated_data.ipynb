# %%
import pandas as pd
import os
import glob
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.metrics import r2_score

# %%
actual_co_ordinate=68

# Set the path to the folder containing the dataset

data_folder = r'C:\Users\LILA\Desktop\RTT-FIngerprinting-with-offset\RTT-Fingerprinting with offset\Dataset\Test_dataset'
#data_folder = 'C:/Users/LILA/RTT-RSS with Kalman/raw_dataset'
# Loop through each CSV file in the folder and read it into a DataFrame
for file_name in os.listdir(data_folder):
     if file_name == (str(actual_co_ordinate)+'.csv'): #if it found filname after defining file path break
        file_path = os.path.join(data_folder, file_name)
        df = pd.read_csv(file_path)
        break
df
# Out:
#      AP1RTT  AP1STDEV  AP1RSS  AP2RTT  AP2STDEV  AP2RSS  AP3RTT  AP3STDEV  \
# 0     1.227     0.126     -53  10.022     0.226     -68   5.618     1.044
# 1     1.256     0.171     -53  10.100     0.165     -68   5.706     1.041
# 2     1.139     0.223     -53  10.061     0.145     -68   5.676     1.054
# 3     1.344     0.116     -48  10.061     0.165     -68   5.676     1.113
# 4     1.314     0.065     -53  10.139     0.085     -68   5.706     1.039
# ..      ...       ...     ...     ...       ...     ...     ...       ...
# 218   1.285     0.661     -53  10.256     0.126     -68   5.969     0.907
# 219   1.314     0.165     -54  10.256     0.141     -68   6.204     0.874
# 220   1.383     0.136     -54  10.295     0.126     -68   6.409     0.577
# 221   1.109     1.239     -52  10.373     0.065     -68   5.764     1.011
# 222   1.773     1.100     -49  10.178     0.199     -69   5.442     1.100
#
#      AP3RSS  x  y  x1  y1  x2  y2  x3  y3
# 0       -64  6  8   7   9   7   0   0   9
# 1       -64  6  8   7   9   7   0   0   9
# 2       -63  6  8   7   9   7   0   0   9
# 3       -64  6  8   7   9   7   0   0   9
# 4       -64  6  8   7   9   7   0   0   9
# ..      ... .. ..  ..  ..  ..  ..  ..  ..
# 218     -60  6  8   7   9   7   0   0   9
# 219     -59  6  8   7   9   7   0   0   9
# 220     -56  6  8   7   9   7   0   0   9
# 221     -58  6  8   7   9   7   0   0   9
# 222     -62  6  8   7   9   7   0   0   9
#
# [223 rows x 17 columns]

# %%
df['True_range1']=np.sqrt((df.x-df.x1)**2+(df.y-df.y1)**2)
df['True_range2']=np.sqrt((df.x-df.x2)**2+(df.y-df.y2)**2)
df['True_range3']=np.sqrt((df.x-df.x3)**2+(df.y-df.y3)**2)
df
# Out:
#      AP1RTT  AP1STDEV  AP1RSS  AP2RTT  AP2STDEV  AP2RSS  AP3RTT  AP3STDEV  \
# 0     1.227     0.126     -53  10.022     0.226     -68   5.618     1.044
# 1     1.256     0.171     -53  10.100     0.165     -68   5.706     1.041
# 2     1.139     0.223     -53  10.061     0.145     -68   5.676     1.054
# 3     1.344     0.116     -48  10.061     0.165     -68   5.676     1.113
# 4     1.314     0.065     -53  10.139     0.085     -68   5.706     1.039
# ..      ...       ...     ...     ...       ...     ...     ...       ...
# 218   1.285     0.661     -53  10.256     0.126     -68   5.969     0.907
# 219   1.314     0.165     -54  10.256     0.141     -68   6.204     0.874
# 220   1.383     0.136     -54  10.295     0.126     -68   6.409     0.577
# 221   1.109     1.239     -52  10.373     0.065     -68   5.764     1.011
# 222   1.773     1.100     -49  10.178     0.199     -69   5.442     1.100
#
#      AP3RSS  x  y  x1  y1  x2  y2  x3  y3  True_range1  True_range2  \
# 0       -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# 1       -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# 2       -63  6  8   7   9   7   0   0   9     1.414214     8.062258
# 3       -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# 4       -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# ..      ... .. ..  ..  ..  ..  ..  ..  ..          ...          ...
# 218     -60  6  8   7   9   7   0   0   9     1.414214     8.062258
# 219     -59  6  8   7   9   7   0   0   9     1.414214     8.062258
# 220     -56  6  8   7   9   7   0   0   9     1.414214     8.062258
# 221     -58  6  8   7   9   7   0   0   9     1.414214     8.062258
# 222     -62  6  8   7   9   7   0   0   9     1.414214     8.062258
#
#      True_range3
# 0       6.082763
# 1       6.082763
# 2       6.082763
# 3       6.082763
# 4       6.082763
# ..           ...
# 218     6.082763
# 219     6.082763
# 220     6.082763
# 221     6.082763
# 222     6.082763
#
# [223 rows x 20 columns]

# %%
offset1=np.mean(df.AP1RTT-df.True_range1)
offset2=np.mean(df.AP2RTT-df.True_range2)
offset3=np.mean(df.AP3RTT-df.True_range3)
print(offset1)
print(offset2)
print(offset3)
# Out:
# -0.19752746371838661
# 2.0134552561857557
# -0.3136324854551698

# %%
df['AP1RTT']= df['AP1RTT']-offset1
df['AP2RTT']= df['AP2RTT']-offset2
df['AP3RTT']= df['AP3RTT']-offset3
df
# Out:
#        AP1RTT  AP1STDEV  AP1RSS    AP2RTT  AP2STDEV  AP2RSS    AP3RTT  \
# 0    1.424527     0.126     -53  8.008545     0.226     -68  5.931632
# 1    1.453527     0.171     -53  8.086545     0.165     -68  6.019632
# 2    1.336527     0.223     -53  8.047545     0.145     -68  5.989632
# 3    1.541527     0.116     -48  8.047545     0.165     -68  5.989632
# 4    1.511527     0.065     -53  8.125545     0.085     -68  6.019632
# ..        ...       ...     ...       ...       ...     ...       ...
# 218  1.482527     0.661     -53  8.242545     0.126     -68  6.282632
# 219  1.511527     0.165     -54  8.242545     0.141     -68  6.517632
# 220  1.580527     0.136     -54  8.281545     0.126     -68  6.722632
# 221  1.306527     1.239     -52  8.359545     0.065     -68  6.077632
# 222  1.970527     1.100     -49  8.164545     0.199     -69  5.755632
#
#      AP3STDEV  AP3RSS  x  y  x1  y1  x2  y2  x3  y3  True_range1  True_range2  \
# 0       1.044     -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# 1       1.041     -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# 2       1.054     -63  6  8   7   9   7   0   0   9     1.414214     8.062258
# 3       1.113     -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# 4       1.039     -64  6  8   7   9   7   0   0   9     1.414214     8.062258
# ..        ...     ... .. ..  ..  ..  ..  ..  ..  ..          ...          ...
# 218     0.907     -60  6  8   7   9   7   0   0   9     1.414214     8.062258
# 219     0.874     -59  6  8   7   9   7   0   0   9     1.414214     8.062258
# 220     0.577     -56  6  8   7   9   7   0   0   9     1.414214     8.062258
# 221     1.011     -58  6  8   7   9   7   0   0   9     1.414214     8.062258
# 222     1.100     -62  6  8   7   9   7   0   0   9     1.414214     8.062258
#
#      True_range3
# 0       6.082763
# 1       6.082763
# 2       6.082763
# 3       6.082763
# 4       6.082763
# ..           ...
# 218     6.082763
# 219     6.082763
# 220     6.082763
# 221     6.082763
# 222     6.082763
#
# [223 rows x 20 columns]

# %%
# # Specify the file name and path where you want to save the file
file_path = 'Offset_Test_'+str(actual_co_ordinate)+'.csv'


# Save the DataFrame to a CSV file using the to_csv() method
df.to_csv(file_path, index=False)

print(f'File saved to {file_path}!')
# Out:
# File saved to Offset_Test_68.csv!
